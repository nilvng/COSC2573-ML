# %%
from keras.models import Sequential
# from keras.utils import image_dataset_from_directory

# %%
import matplotlib.pyplot as plt
import random
import matplotlib.image as mpimg
# %matplotlib inline
# plt.figure(figsize=(20,20))
img_folder=r'Image_classification_data/binary-task/1'

def display_images(amount, img_folder):
    for i in range(amount):
        file = random.choice(os.listdir(img_folder))
        image_path= os.path.join(img_folder, file)
        img=mpimg.imread(image_path)
        ax=plt.subplot(1,amount,i+1)
        ax.title.set_text(file)
        plt.imshow(img)

display_images(5, img_folder)

# %%
img_folder=r'Image_classification_data/binary-task/0'
display_images(5, img_folder)

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator()
path = "Image_classification_data/split_binary-task/train"
train_bin = datagen.flow_from_directory(path, class_mode="categorical")
# Out:
# Found 16223 images belonging to 2 classes.

# %%
path = "Image_classification_data/split_binary-task/val"
val_bin = datagen.flow_from_directory(path, class_mode="categorical")
# Out:
# Found 4057 images belonging to 2 classes.

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

path = "Image_classification_data/split_binary-task/train"
train_bin = image_dataset_from_directory(path, labels="inferred", image_size=(27,27))
# Out:
# Found 16223 files belonging to 2 classes.

# %%
labels = list(train_bin.unbatch().map(lambda x, y: y))
print(len(labels))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7f7a39c00a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7f7a39c00a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 16223

# %%
path = "Image_classification_data/split_binary-task/val"
val_bin = image_dataset_from_directory(path, labels="inferred", image_size=(27,27))
# Out:
# Found 4057 files belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, InputLayer, BatchNormalization, Dropout
from keras.applications import xception
from keras.losses import BinaryCrossentropy
# model = xception(weights=None, input_shape=(256, 256, 3), classes=10)

#build a sequential model
model_ann = Sequential()
model_ann.add(Dense(16, input_shape=[27,27,3], activation='relu'))
model_ann.add(Dropout(0.4))
model_ann.add(Dense(32, activation='relu'))
model_ann.add(Dropout(0.6))
model_ann.add(Flatten())
model_ann.add(Dense(2, activation='softmax'))

# compile model
model.compile(loss=BinaryCrossentropy(), optimizer="adam", metrics=['accuracy'])
# fit on data for 30 epochs
model.fit(train_bin, epochs=10, validation_data=val_bin)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f7a3615ca70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f7a3615ca70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 506/507 [============================>.] - ETA: 0s - loss: 0.2368 - accuracy: 0.3487WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7ad37367a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7ad37367a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 507/507 [==============================] - 39s 74ms/step - loss: 0.2371 - accuracy: 0.3486 - val_loss: 0.6014 - val_accuracy: 0.3485
# Epoch 2/10
# 507/507 [==============================] - 31s 60ms/step - loss: 0.2248 - accuracy: 0.3486 - val_loss: 2.6138 - val_accuracy: 0.3485
# Epoch 3/10
# 507/507 [==============================] - 30s 59ms/step - loss: 0.2196 - accuracy: 0.3486 - val_loss: 1.9429 - val_accuracy: 0.3485
# Epoch 4/10
# 507/507 [==============================] - 33s 66ms/step - loss: 0.2104 - accuracy: 0.3486 - val_loss: 1.3893 - val_accuracy: 0.3485
# Epoch 5/10
# 507/507 [==============================] - 32s 63ms/step - loss: 0.2024 - accuracy: 0.3486 - val_loss: 0.9839 - val_accuracy: 0.3485
# Epoch 6/10
# 507/507 [==============================] - 35s 70ms/step - loss: 0.1981 - accuracy: 0.3486 - val_loss: 1.0860 - val_accuracy: 0.3485
# Epoch 7/10
# 507/507 [==============================] - 41s 80ms/step - loss: 0.1934 - accuracy: 0.3486 - val_loss: 0.4272 - val_accuracy: 0.3485
# Epoch 8/10
# 507/507 [==============================] - 29s 58ms/step - loss: 0.1798 - accuracy: 0.3486 - val_loss: 1.1271 - val_accuracy: 0.3485
# Epoch 9/10
# 507/507 [==============================] - 54s 106ms/step - loss: 0.1722 - accuracy: 0.3486 - val_loss: 1.1753 - val_accuracy: 0.3485
# Epoch 10/10
# 507/507 [==============================] - 36s 70ms/step - loss: 0.1673 - accuracy: 0.3486 - val_loss: 0.9754 - val_accuracy: 0.3485

# %%
from keras.layers import Conv2D, MaxPooling2D,Activation, Flatten, Dense, InputLayer, BatchNormalization, Dropout
from keras import Model
model = Sequential()
model.add(Conv2D(16,(5,5),padding='valid',input_shape = [27,27,3]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'valid'))
model.add(Dropout(0.4))
model.add(Conv2D(32,(5,5),padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'valid'))
model.add(Dropout(0.6))
# model.add(Conv2D(64,(5,5),padding='valid'))
# model.add(Activation('relu'))
# model.add(Dropout(0.8))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

model_feat = Model(inputs=model.input,outputs=model.get_layer('activation_10').output)
feat_train = model_feat.predict(train_bin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ks/c7f10mrs12z35r1mm8xqv_zh0000gn/T/ipykernel_18353/2510556140.py in <module>
#      17 model.add(Activation('softmax'))
#      18
# ---> 19 model_feat = Model(inputs=model.input,outputs=model.get_layer('activation_10').output)
#      20 feat_train = model_feat.predict(train_bin)
#
# ~/opt/anaconda3/envs/keras-env/lib/python3.7/site-packages/keras/engine/training.py in get_layer(self, name, index)
#    2826         if layer.name == name:
#    2827           return layer
# -> 2828       raise ValueError(f'No such layer: {name}. Existing layers are: '
#    2829                        f'{list(layer.name for layer in self.layers)}.')
#    2830     raise ValueError('Provide either a layer name or layer index at '
#
# ValueError: No such layer: activation_10. Existing layers are: ['conv2d_30', 'activation_11', 'max_pooling2d_29', 'dropout_17', 'conv2d_31', 'activation_12', 'max_pooling2d_30', 'dropout_18', 'flatten_11', 'dense_27', 'activation_13'].
